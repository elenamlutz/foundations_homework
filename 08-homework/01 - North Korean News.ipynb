# %% [markdown]
# # North Korean News
#
# Scrape the North Korean news agency http://kcna.kp
#
# Save a CSV called `nk-news.csv`. This file should include:
#
# * The **article headline**
# * The value of **`onclick`** (they don't have normal links)
# * The **article ID** (for example, the article ID for `fn_showArticle("AR0125885", "", "NT00", "L")` is `AR0125885`
#
# The last part is easiest using pandas. Be sure you don't save the index!
#
# * _**Tip:** If you're using requests+BeautifulSoup, you can always look at response.text to see if the page looks like what you think it looks like_
# * _**Tip:** Check your URL to make sure it is what you think it should be!_
# * _**Tip:** Does it look different if you scrape with BeautifulSoup compared to if you scrape it with Selenium?_
# * _**Tip:** For the last part, how do you pull out part of a string from a longer string?_
# * _**Tip:** `expand=False` is helpful if you want to assign a single new column when extracting_
# * _**Tip:** `(` and `)` mean something special in regular expressions, so you have to say "no really seriously I mean `(`" by using `\(` instead_
# * _**Tip:** if your `.*` is taking up too much stuff, you can try `.*?` instead, which instead of "take as much as possible" it means "take only as much as needed"_

# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome()

# %%
driver.get('http://kcna.kp')

# %%
items = driver.find_elements_by_class_name('titlebet')
rows = []
for item in items:
    row = {}
    row['headline'] = item.text
    row['onclick'] = item.get_attribute('onclick')
    row['ID'] = item.get_attribute('onclick')[16:25]
    print(row)
    rows.append(row)
# Out:
# {'headline': '김정은동지께서 김대중 전 대통령의 부인 리희호녀사의 유가족들에게 조의문을 보내시였다', 'onclick': 'fn_showArticle("AR0126135", "", "NT00", "L")', 'ID': 'AR0126135'}
# {'headline': '경애하는 최고령도자 김정은동지께서 김대중 전 대통령의 부인 리희호녀사의 유가족들에게 조의문과 조화를 보내시였다', 'onclick': 'fn_showArticle("AR0126133", "", "NT00", "L")', 'ID': 'AR0126133'}
# {'headline': '김정은동지께서 로씨야대통령에게 축전을 보내시였다', 'onclick': 'fn_showArticle("AR0126098", "", "NT00", "L")', 'ID': 'AR0126098'}
# {'headline': '경애하는 최고령도자 김정은동지께서 조선인민군 제2기 제7차 군인가족예술소조경연에서 당선된 군부대들의 군인가족예술소조원들과 기념사진을 찍으시였다', 'onclick': 'fn_showArticle("AR0125885", "", "NT00", "L")', 'ID': 'AR0125885'}
# {'headline': '김정은동지께서 꾸바공산당 중앙위원회 제1비서에게 축전을 보내시였다', 'onclick': 'fn_showArticle("AR0125876", "", "NT00", "L")', 'ID': 'AR0125876'}
# {'headline': '대집단체조와 예술공연 《인민의 나라》 개막', 'onclick': 'fn_showArticle("AR0125856", "", "NT00", "L")', 'ID': 'AR0125856'}
# {'headline': '중앙미술전시회 개막', 'onclick': 'fn_showArticle("AR0126318", "", "NT41", "L")', 'ID': 'AR0126318'}
# {'headline': '중앙연구토론회 진행', 'onclick': 'fn_showArticle("AR0126314", "", "NT41", "L")', 'ID': 'AR0126314'}
# {'headline': '김일성동지와 김정일동지의 동상을 찾아 총련 지바현상공회대표단 경모의 정 표시', 'onclick': 'fn_showArticle("AR0126313", "", "NT41", "L")', 'ID': 'AR0126313'}
# {'headline': '총련 지바현상공회대표단 도착', 'onclick': 'fn_showArticle("AR0126312", "", "NT41", "L")', 'ID': 'AR0126312'}
# {'headline': '정방산이 전하는 이야기', 'onclick': 'fn_showArticle("AR0126310", "", "NT41", "L")', 'ID': 'AR0126310'}
# {'headline': '남조선단체들 민족분렬을 끝장내기 위한 투쟁에 나설것을 호소', 'onclick': 'fn_showArticle("AR0126309", "", "NT41", "L")', 'ID': 'AR0126309'}
# {'headline': '남조선단체들 4.27판문점선언과 9월평양공동선언의 전면적리행을 요구', 'onclick': 'fn_showArticle("AR0126298", "", "NT41", "L")', 'ID': 'AR0126298'}
# {'headline': '환경보호에 이바지할 연구성과들', 'onclick': 'fn_showArticle("AR0126297", "", "NT41", "L")', 'ID': 'AR0126297'}
# {'headline': '천수백만t의 석탄매장량 탐사', 'onclick': 'fn_showArticle("AR0126296", "", "NT41", "L")', 'ID': 'AR0126296'}
# {'headline': '최룡해동지 세이쉘공화국 국경절을 축하', 'onclick': 'fn_showArticle("AR0126295", "", "NT41", "L")', 'ID': 'AR0126295'}
# {'headline': '《로동신문》 혁명과 건설에서 주체성과 민족성을 고수해나갈데 대해 강조', 'onclick': 'fn_showArticle("AR0126293", "", "NT41", "L")', 'ID': 'AR0126293'}
# {'headline': '주체108(2019)년 6월 18일 신문개관', 'onclick': 'fn_showArticle("AR0126292", "", "NT41", "L")', 'ID': 'AR0126292'}
# {'headline': '선물동물들의 마리수가 늘어난다--중앙동물원에서', 'onclick': 'fn_showArticle("AR0126291", "", "NT41", "L")', 'ID': 'AR0126291'}
# {'headline': '6.12조미공동성명채택 1돐에 즈음하여 로씨야,알제리인사 담화 발표', 'onclick': 'fn_showArticle("AR0126290", "", "NT41", "L")', 'ID': 'AR0126290'}
# {'headline': '김일성주석회고위원회 쿠웨이트에서 결성', 'onclick': 'fn_showArticle("AR0126289", "", "NT41", "L")', 'ID': 'AR0126289'}
# {'headline': '김일성주석회고 수리아통일사회주의자당위원회 결성', 'onclick': 'fn_showArticle("AR0126288", "", "NT41", "L")', 'ID': 'AR0126288'}
# {'headline': '김정은동지께 베네수엘라 까라보보주 나구아나구아시가 최고훈장을 수여해드리였다', 'onclick': 'fn_showArticle("AR0126287", "", "NT41", "L")', 'ID': 'AR0126287'}
# {'headline': '중국공산당 중앙위원회 총서기,중화인민공화국 주석 습근평동지가 조선을 방문한다', 'onclick': 'fn_showArticle("AR0126286", "", "NT41", "L")', 'ID': 'AR0126286'}
# {'headline': '평안남도양생원 새로 건설', 'onclick': 'fn_showArticle("AR0126285", "", "NT41", "L")', 'ID': 'AR0126285'}
# {'headline': '조선에서 적십자활동 활발', 'onclick': 'fn_showArticle("AR0126284", "", "NT41", "L")', 'ID': 'AR0126284'}
# {'headline': '평양국제건강 및 의료기구부문 과학기술전시회 개막', 'onclick': 'fn_showArticle("AR0126283", "", "NT41", "L")', 'ID': 'AR0126283'}
# {'headline': '조선정부대표단 나이제리아방문을 마치고 귀국', 'onclick': 'fn_showArticle("AR0126282", "", "NT41", "L")', 'ID': 'AR0126282'}
# {'headline': '김재룡동지 덕천지구탄광련합기업소 현지료해', 'onclick': 'fn_showArticle("AR0126281", "", "NT41", "L")', 'ID': 'AR0126281'}
# {'headline': '김정은각하의 존함은 인류의 보호자,은인으로 길이 빛날것이라고 여러 나라 인사들 칭송', 'onclick': 'fn_showArticle("AR0126280", "", "NT41", "L")', 'ID': 'AR0126280'}
# {'headline': '100여만마리의 새끼가재미 방류', 'onclick': 'fn_showArticle("AR0126279", "", "NT41", "L")', 'ID': 'AR0126279'}
# {'headline': '2018년-2019년 조선민주주의인민공화국 1부류축구련맹전소식(14)', 'onclick': 'fn_showArticle("AR0126278", "", "NT41", "L")', 'ID': 'AR0126278'}
# {'headline': '량면술책은 통하지 않는다--조선중앙통신사 론평', 'onclick': 'fn_showArticle("AR0126277", "", "NT41", "L")', 'ID': 'AR0126277'}
# {'headline': '밭농사의 새 력사를 펼치시여--수령님과 일화', 'onclick': 'fn_showArticle("AR0126276", "", "NT41", "L")', 'ID': 'AR0126276'}
# {'headline': '주체108(2019)년 6월 17일 《로동신문》개관', 'onclick': 'fn_showArticle("AR0126262", "", "NT41", "L")', 'ID': 'AR0126262'}
# {'headline': '《로동신문》 과학기술과 교육은 자력갱생대진군의 견인기라고 강조', 'onclick': 'fn_showArticle("AR0126260", "", "NT41", "L")', 'ID': 'AR0126260'}
# {'headline': '반제민전 평양지부 대표 공동선언리행에 총력을 경주해갈것이라고 강조', 'onclick': 'fn_showArticle("AR0126233", "", "NT04", "L")', 'ID': 'AR0126233'}
# {'headline': '6.15공동선언실천 민족공동위원회 결의문', 'onclick': 'fn_showArticle("AR0126228", "", "NT04", "L")', 'ID': 'AR0126228'}
# {'headline': '조국통일연구원 상보', 'onclick': 'fn_showArticle("AR0125916", "", "NT04", "L")', 'ID': 'AR0125916'}
# {'headline': '조선민주주의인민공화국 조국평화통일위원회 통일선전국 고발장', 'onclick': 'fn_showArticle("AR0125556", "", "NT04", "L")', 'ID': 'AR0125556'}
# {'headline': '파멸의 운명에 처한자들의 부질없는 대결광증--조선중앙통신사 론평', 'onclick': 'fn_showArticle("AR0125472", "", "NT04", "L")', 'ID': 'AR0125472'}
# {'headline': '반제민전 중앙위원회 전국민이 일치단합하여 보수적페세력들을 척결하고 항쟁용사들이 바라던 념원을 성취하자고 호소', 'onclick': 'fn_showArticle("AR0125350", "", "NT04", "L")', 'ID': 'AR0125350'}
# {'headline': '거세찬 역풍을 몰아오는 《북풍몰이》--조선중앙통신사 론평', 'onclick': 'fn_showArticle("AR0125232", "", "NT04", "L")', 'ID': 'AR0125232'}
# {'headline': '최룡해동지 세이쉘공화국 국경절을 축하', 'onclick': 'fn_showArticle("AR0126295", "", "NT03", "L")', 'ID': 'AR0126295'}
# {'headline': '6.12조미공동성명채택 1돐에 즈음하여 로씨야,알제리인사 담화 발표', 'onclick': 'fn_showArticle("AR0126290", "", "NT03", "L")', 'ID': 'AR0126290'}
# {'headline': '김일성주석회고위원회 쿠웨이트에서 결성', 'onclick': 'fn_showArticle("AR0126289", "", "NT03", "L")', 'ID': 'AR0126289'}
# {'headline': '김일성주석회고 수리아통일사회주의자당위원회 결성', 'onclick': 'fn_showArticle("AR0126288", "", "NT03", "L")', 'ID': 'AR0126288'}
# {'headline': '김정은동지께 베네수엘라 까라보보주 나구아나구아시가 최고훈장을 수여해드리였다', 'onclick': 'fn_showArticle("AR0126287", "", "NT03", "L")', 'ID': 'AR0126287'}
# {'headline': '중국공산당 중앙위원회 총서기,중화인민공화국 주석 습근평동지가 조선을 방문한다', 'onclick': 'fn_showArticle("AR0126286", "", "NT03", "L")', 'ID': 'AR0126286'}
# {'headline': '조선에서 적십자활동 활발', 'onclick': 'fn_showArticle("AR0126284", "", "NT03", "L")', 'ID': 'AR0126284'}
# {'headline': '평양국제건강 및 의료기구부문 과학기술전시회 개막', 'onclick': 'fn_showArticle("AR0126283", "", "NT03", "L")', 'ID': 'AR0126283'}
# {'headline': '사회적진보와 발전을 위하여', 'onclick': 'fn_showArticle("AR0126311", "", "NT06", "L")', 'ID': 'AR0126311'}
018년-2019년 조선민주주의인민공화국 1부류축구련맹전소식(13)', 'onclick': 'fn_showArticle("AR0126058", "", "NT11", "L")', 'ID': 'AR0126058'}
# {'headline': '2018년-2019년 조선민주주의인민공화국 녀자 1부류축구련맹전소식(11)', 'onclick': 'fn_showArticle("AR0126009", "", "NT11", "L")', 'ID': 'AR0126009'}
# {'headline': '환경보호에 이바지할 연구성과들', 'onclick': 'fn_showArticle("AR0126297", "", "NT09", "L")', 'ID': 'AR0126297'}
# {'headline': '평양국제건강 및 의료기구부문 과학기술전시회 개막', 'onclick': 'fn_showArticle("AR0126283", "", "NT09", "L")', 'ID': 'AR0126283'}
# {'headline': '새로운 정밀주조석고제조와 주조기술 연구개발', 'onclick': 'fn_showArticle("AR0126122", "", "NT09", "L")', 'ID': 'AR0126122'}
# {'headline': '《온실남새부문 과학기술토론회-2019》 개막', 'onclick': 'fn_showArticle("AR0126095", "", "NT09", "L")', 'ID': 'AR0126095'}
# {'headline': '새로운 남새품종육종사업을 활발히--평양남새과학연구소에서', 'onclick': 'fn_showArticle("AR0126054", "", "NT09", "L")', 'ID': 'AR0126054'}
# {'headline': '도입전망이 큰 새로운 배낭식전동분무기 제작', 'onclick': 'fn_showArticle("AR0126038", "", "NT09", "L")', 'ID': 'AR0126038'}
# {'headline': '《전국소년과학환상문예작품 및 모형전시회-2019》 진행', 'onclick': 'fn_showArticle("AR0125978", "", "NT09", "L")', 'ID': 'AR0125978'}
# {'headline': '로씨야에서 통신위성 발사', 'onclick': 'fn_showArticle("AR0125784", "", "NT09", "L")', 'ID': 'AR0125784'}
# {'headline': '조선에서 우량한 과일품종 40여개 육종,국가품종으로 등록', 'onclick': 'fn_showArticle("AR0125737", "", "NT09", "L")', 'ID': 'AR0125737'}
# {'headline': '남부수단에서 정보자료쎈터 설립', 'onclick': 'fn_showArticle("AR0125722", "", "NT09", "L")', 'ID': 'AR0125722'}
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# <ipython-input-40-a3bcbfea52b9> in <module>
#       3 for item in items:
#       4     row = {}
# ----> 5     row['headline'] = item.text
#       6     row['onclick'] = item.get_attribute('onclick')
#       7     row['ID'] = item.get_attribute('onclick')[16:25]
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/selenium/webdriver/remote/webelement.py in text(self)
#      74     def text(self):
#      75         """The text of the element."""
# ---> 76         return self._execute(Command.GET_ELEMENT_TEXT)['value']
#      77
#      78     def click(self):
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=75.0.3770.100)
#   (Driver info: chromedriver=74.0.3729.6 (255758eccf3d244491b8a1317aa76e1ce10d57e9-refs/branch-heads/3729@{#29}),platform=Mac OS X 10.14.0 x86_64)

# %%
import pandas as pd
df = pd.DataFrame(rows)
df
# Out:
#             ID                                           headline  \
# 0    AR0126135     김정은동지께서 김대중 전 대통령의 부인 리희호녀사의 유가족들에게 조의문을 보내시였다
# 1    AR0126133  경애하는 최고령도자 김정은동지께서 김대중 전 대통령의 부인 리희호녀사의 유가족들에게...
# 2    AR0126098                         김정은동지께서 로씨야대통령에게 축전을 보내시였다
# 3    AR0125885  경애하는 최고령도자 김정은동지께서 조선인민군 제2기 제7차 군인가족예술소조경연에서 ...
# 4    AR0125876               김정은동지께서 꾸바공산당 중앙위원회 제1비서에게 축전을 보내시였다
# 5    AR0125856                            대집단체조와 예술공연 《인민의 나라》 개막
# 6    AR0126318                                         중앙미술전시회 개막
# 7    AR0126314                                         중앙연구토론회 진행
# 8    AR0126313         김일성동지와 김정일동지의 동상을 찾아 총련 지바현상공회대표단 경모의 정 표시
# 9    AR0126312                                    총련 지바현상공회대표단 도착
# 10   AR0126310                                       정방산이 전하는 이야기
# 11   AR0126309                   남조선단체들 민족분렬을 끝장내기 위한 투쟁에 나설것을 호소
# 12   AR0126298              남조선단체들 4.27판문점선언과 9월평양공동선언의 전면적리행을 요구
# 13   AR0126297                                   환경보호에 이바지할 연구성과들
# 14   AR0126296                                    천수백만t의 석탄매장량 탐사
# 15   AR0126295                               최룡해동지 세이쉘공화국 국경절을 축하
# 16   AR0126293             《로동신문》 혁명과 건설에서 주체성과 민족성을 고수해나갈데 대해 강조
# 17   AR0126292                           주체108(2019)년 6월 18일 신문개관
# 18   AR0126291                          선물동물들의 마리수가 늘어난다--중앙동물원에서
# 19   AR0126290              6.12조미공동성명채택 1돐에 즈음하여 로씨야,알제리인사 담화 발표
# 20   AR0126289                               김일성주석회고위원회 쿠웨이트에서 결성
# 21   AR0126288                          김일성주석회고 수리아통일사회주의자당위원회 결성
# 22   AR0126287          김정은동지께 베네수엘라 까라보보주 나구아나구아시가 최고훈장을 수여해드리였다
# 23   AR0126286         중국공산당 중앙위원회 총서기,중화인민공화국 주석 습근평동지가 조선을 방문한다
# 24   AR0126285                                      평안남도양생원 새로 건설
# 25   AR0126284                                      조선에서 적십자활동 활발
# 26   AR0126283                         평양국제건강 및 의료기구부문 과학기술전시회 개막
# 27   AR0126282                            조선정부대표단 나이제리아방문을 마치고 귀국
# 28   AR0126281                             김재룡동지 덕천지구탄광련합기업소 현지료해
# 29   AR0126280     김정은각하의 존함은 인류의 보호자,은인으로 길이 빛날것이라고 여러 나라 인사들 칭송
# ..         ...                                                ...
# 89   AR0126193
# 90   AR0126164
# 91   AR0126162
# 92   AR0126154
# 93   AR0126153
# 94   AR0126313         김일성동지와 김정일동지의 동상을 찾아 총련 지바현상공회대표단 경모의 정 표시
# 95   AR0126295                               최룡해동지 세이쉘공화국 국경절을 축하
# 96   AR0126287          김정은동지께 베네수엘라 까라보보주 나구아나구아시가 최고훈장을 수여해드리였다
# 97   AR0126286         중국공산당 중앙위원회 총서기,중화인민공화국 주석 습근평동지가 조선을 방문한다
# 98   AR0126281                             김재룡동지 덕천지구탄광련합기업소 현지료해
# 99   AR0126277                          량면술책은 통하지 않는다--조선중앙통신사 론평
# 100  AR0126169    조선에서 도(직할시),시(구역),군인민회의 대의원선거를 위한 중앙선거지도위원회를 조직
# 101  AR0126127          최룡해동지 조선과 까자흐스딴사이의 친선협조관계가 강화발전되리라는 확신 표명
# 102  AR0126118                               최룡해동지 필리핀독립 121돐을 축하
# 103  AR0126117                     전범기를 비호하는 목적은 무엇인가--조선중앙통신사 론평
# 104  AR0126278             2018년-2019년 조선민주주의인민공화국 1부류축구련맹전소식(14)
# 105  AR0126227                          보천보홰불상체육경기대회 도로이어달리기경기 진행
# 106  AR0126226          2018년-2019년 조선민주주의인민공화국 녀자 1부류축구련맹전소식(12)
# 107  AR0126058             2018년-2019년 조선민주주의인민공화국 1부류축구련맹전소식(13)
# 108  AR0126009          2018년-2019년 조선민주주의인민공화국 녀자 1부류축구련맹전소식(11)
# 109  AR0126297                                   환경보호에 이바지할 연구성과들
# 110  AR0126283                         평양국제건강 및 의료기구부문 과학기술전시회 개막
# 111  AR0126122                            새로운 정밀주조석고제조와 주조기술 연구개발
# 112  AR0126095                           《온실남새부문 과학기술토론회-2019》 개막
# 113  AR0126054                     새로운 남새품종육종사업을 활발히--평양남새과학연구소에서
# 114  AR0126038                            도입전망이 큰 새로운 배낭식전동분무기 제작
# 115  AR0125978                     《전국소년과학환상문예작품 및 모형전시회-2019》 진행
# 116  AR0125784                                      로씨야에서 통신위성 발사
# 117  AR0125737                    조선에서 우량한 과일품종 40여개 육종,국가품종으로 등록
# 118  AR0125722                                   남부수단에서 정보자료쎈터 설립
#
#                                           onclick
# 0    fn_showArticle("AR0126135", "", "NT00", "L")
# 1    fn_showArticle("AR0126133", "", "NT00", "L")
# 2    fn_showArticle("AR0126098", "", "NT00", "L")
# 3    fn_showArticle("AR0125885", "", "NT00", "L")
# 4    fn_showArticle("AR0125876", "", "NT00", "L")
# 5    fn_showArticle("AR0125856", "", "NT00", "L")
# 6    fn_showArticle("AR0126318", "", "NT41", "L")
# 7    fn_showArticle("AR0126314", "", "NT41", "L")
# 8    fn_showArticle("AR0126313", "", "NT41", "L")
# 9    fn_showArticle("AR0126312", "", "NT41", "L")
# 10   fn_showArticle("AR0126310", "", "NT41", "L")
# 11   fn_showArticle("AR0126309", "", "NT41", "L")
# 12   fn_showArticle("AR0126298", "", "NT41", "L")
# 13   fn_showArticle("AR0126297", "", "NT41", "L")
# 14   fn_showArticle("AR0126296", "", "NT41", "L")
# 15   fn_showArticle("AR0126295", "", "NT41", "L")
# 16   fn_showArticle("AR0126293", "", "NT41", "L")
# 17   fn_showArticle("AR0126292", "", "NT41", "L")
# 18   fn_showArticle("AR0126291", "", "NT41", "L")
# 19   fn_showArticle("AR0126290", "", "NT41", "L")
# 20   fn_showArticle("AR0126289", "", "NT41", "L")
# 21   fn_showArticle("AR0126288", "", "NT41", "L")
# 22   fn_showArticle("AR0126287", "", "NT41", "L")
# 23   fn_showArticle("AR0126286", "", "NT41", "L")
# 24   fn_showArticle("AR0126285", "", "NT41", "L")
# 25   fn_showArticle("AR0126284", "", "NT41", "L")
# 26   fn_showArticle("AR0126283", "", "NT41", "L")
# 27   fn_showArticle("AR0126282", "", "NT41", "L")
# 28   fn_showArticle("AR0126281", "", "NT41", "L")
# 29   fn_showArticle("AR0126280", "", "NT41", "L")
# ..                                            ...
# 89   fn_showArticle("AR0126193", "", "NT05", "L")
# 90   fn_showArticle("AR0126164", "", "NT05", "L")
# 91   fn_showArticle("AR0126162", "", "NT05", "L")
# 92   fn_showArticle("AR0126154", "", "NT05", "L")
# 93   fn_showArticle("AR0126153", "", "NT05", "L")
# 94   fn_showArticle("AR0126313", "", "NT21", "L")
# 95   fn_showArticle("AR0126295", "", "NT21", "L")
# 96   fn_showArticle("AR0126287", "", "NT21", "L")
# 97   fn_showArticle("AR0126286", "", "NT21", "L")
# 98   fn_showArticle("AR0126281", "", "NT21", "L")
# 99   fn_showArticle("AR0126277", "", "NT21", "L")
# 100  fn_showArticle("AR0126169", "", "NT21", "L")
# 101  fn_showArticle("AR0126127", "", "NT21", "L")
# 102  fn_showArticle("AR0126118", "", "NT21", "L")
# 103  fn_showArticle("AR0126117", "", "NT21", "L")
# 104  fn_showArticle("AR0126278", "", "NT11", "L")
# 105  fn_showArticle("AR0126227", "", "NT11", "L")
# 106  fn_showArticle("AR0126226", "", "NT11", "L")
# 107  fn_showArticle("AR0126058", "", "NT11", "L")
# 108  fn_showArticle("AR0126009", "", "NT11", "L")
# 109  fn_showArticle("AR0126297", "", "NT09", "L")
# 110  fn_showArticle("AR0126283", "", "NT09", "L")
# 111  fn_showArticle("AR0126122", "", "NT09", "L")
# 112  fn_showArticle("AR0126095", "", "NT09", "L")
# 113  fn_showArticle("AR0126054", "", "NT09", "L")
# 114  fn_showArticle("AR0126038", "", "NT09", "L")
# 115  fn_showArticle("AR0125978", "", "NT09", "L")
# 116  fn_showArticle("AR0125784", "", "NT09", "L")
# 117  fn_showArticle("AR0125737", "", "NT09", "L")
# 118  fn_showArticle("AR0125722", "", "NT09", "L")
#
# [119 rows x 3 columns]

# %%
df.to_csv('north_korean_news', index=False)
